# %% [markdown]
# Pekerjaan ini mengacu pada studi kasus dari kursus [Udemy: Data Science for Business | 6 Real-world Case Studies](https://www.udemy.com/share/102X3UAEMad15SRX8D/), Bagian 3 "Human Resources Department".
#
# ---
# This work is based on a case study from the course [Udemy: Data Science for Business | 6 Real World Case Studies] (https://www.udemy.com/share/102X3UAEMad15SRX8D/), Part 3 "Human Resources Department".

# %%
# Start writing code here...
